# %% [markdown]
# ## Titanic Decision Tree: Step-by-Step with Entropy/Information Gain\n",
# ##    "This notebook will guide you through importing the Titanic dataset from Kaggle, preprocessing it, and building a Decision Tree using entropy (information gain), displaying each step.

# %% [markdown]
# ### using classic titanic dataset

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('../Datasets/train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import pandas as pd
import numpy as np
import math
from pprint import pprint

# Load the dataset (assumes it's in the same folder)
# df = pd.read_csv("titanic.csv")

# Simplify dataset: drop unnecessary columns
df = df[['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']]

# Handle missing values
df.dropna(inplace=True)

# Convert categorical columns to numeric
df['Sex'] = df['Sex'].map({'male': 0, 'female': 1})
df['Embarked'] = df['Embarked'].map({'C': 0, 'Q': 1, 'S': 2})

# Discretize continuous features for clarity
df['Age'] = pd.cut(df['Age'], bins=4, labels=[0, 1, 2,3])
df['Fare'] = pd.qcut(df['Fare'], 2, labels=[0, 1])

# Reset index
df.reset_index(drop=True, inplace=True)

# -------------------------
# Helper Functions
# -------------------------

def entropy(data):
    """Calculate entropy of the target column (Survived)."""
    values, counts = np.unique(data, return_counts=True)
    ent = 0
    for i in range(len(values)):
        p = counts[i] / np.sum(counts)
        ent -= p * np.log2(p)
    return ent

def info_gain(data, feature, target_name="Survived"):
    """Calculate information gain of a feature."""
    total_entropy = entropy(data[target_name])
    vals, counts = np.unique(data[feature], return_counts=True)

    weighted_entropy = 0
    for i in range(len(vals)):
        subset = data[data[feature] == vals[i]]
        weighted_entropy += (counts[i] / np.sum(counts)) * entropy(subset[target_name])

    return total_entropy - weighted_entropy

def best_split(data, features):
    """Find the best feature to split on."""
    gains = {}
    for feature in features:
        gains[feature] = info_gain(data, feature)
    best = max(gains, key=gains.get)
    return best, gains

# -------------------------
# Decision Tree Algorithm
# -------------------------

def build_tree(data, features, depth=0):
    target = data['Survived']
    
    # If all examples have the same label
    if len(np.unique(target)) == 1:
        return np.unique(target)[0]
    
    # If no more features to split
    if len(features) == 0:
        return target.mode()[0]

    # Choose the best feature
    best_feat, gains = best_split(data, features)
    
    # Print progress at this level
    print(f"{'|   ' * depth}Split on: {best_feat}")
    for f in gains:
        print(f"{'|   ' * depth} - Info Gain of {f}: {gains[f]:.4f}")

    tree = {best_feat: {}}
    remaining_features = [f for f in features if f != best_feat]

    for val in sorted(data[best_feat].unique()):
        subset = data[data[best_feat] == val]
        print(f"{'|   ' * depth}-> Branch [{best_feat} = {val}] with {len(subset)} rows")

        if subset.empty:
            tree[best_feat][val] = target.mode()[0]
        else:
            subtree = build_tree(subset, remaining_features, depth + 1)
            tree[best_feat][val] = subtree

    return tree


# -------------------------
# Run and Visualize the Tree
# -------------------------

features = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']
decision_tree = build_tree(df, features)

print("\nFinal Decision Tree:")
pprint(decision_tree)
# Out:
# Split on: Sex
#  - Info Gain of Pclass: 0.0940
#  - Info Gain of Sex: 0.2141
#  - Info Gain of Age: 0.0068
#  - Info Gain of SibSp: 0.0249
#  - Info Gain of Parch: 0.0307
#  - Info Gain of Fare: 0.0650
#  - Info Gain of Embarked: 0.0279
# -> Branch [Sex = 0] with 453 rows
# |   Split on: Pclass
# |    - Info Gain of Pclass: 0.0415
# |    - Info Gain of Age: 0.0091
# |    - Info Gain of SibSp: 0.0210
# |    - Info Gain of Parch: 0.0176
# |    - Info Gain of Fare: 0.0365
# |    - Info Gain of Embarked: 0.0176
# |   -> Branch [Pclass = 1] with 101 rows
# |   |   Split on: Age
# |   |    - Info Gain of Age: 0.0668
# |   |    - Info Gain of SibSp: 0.0177
# |   |    - Info Gain of Parch: 0.0247
# |   |    - Info Gain of Fare: 0.0296
# |   |    - Info Gain of Embarked: 0.0105
# |   |   -> Branch [Age = 0] with 7 rows
# |   |   |   Split on: Parch
# |   |   |    - Info Gain of SibSp: 0.4138
# |   |   |    - Info Gain of Parch: 0.4696
# |   |   |    - Info Gain of Fare: 0.0000
# |   |   |    - Info Gain of Embarked: 0.0060
# |   |   |   -> Branch [Parch = 0] with 2 rows
# |   |   |   -> Branch [Parch = 2] with 5 rows
# |   |   |   |   Split on: SibSp
# |   |   |   |    - Info Gain of SibSp: 0.7219
# |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |    - Info Gain of Embarked: 0.0729
# |   |   |   |   -> Branch [SibSp = 0] with 2 rows
# |   |   |   |   -> Branch [SibSp = 1] with 2 rows
# |   |   |   |   -> Branch [SibSp = 3] with 1 rows
# |   |   -> Branch [Age = 1] with 44 rows
# |   |   |   Split on: Fare
# |   |   |    - Info Gain of SibSp: 0.0075
# |   |   |    - Info Gain of Parch: 0.0028
# |   |   |    - Info Gain of Fare: 0.0975
# |   |   |    - Info Gain of Embarked: 0.0015
# |   |   |   -> Branch [Fare = 0] with 4 rows
# |   |   |   -> Branch [Fare = 1] with 40 rows
# |   |   |   |   Split on: Parch
# |   |   |   |    - Info Gain of SibSp: 0.0014
# |   |   |   |    - Info Gain of Parch: 0.0100
# |   |   |   |    - Info Gain of Embarked: 0.0015
# |   |   |   |   -> Branch [Parch = 0] with 31 rows
# |   |   |   |   |   Split on: SibSp
# |   |   |   |   |    - Info Gain of SibSp: 0.0091
# |   |   |   |   |    - Info Gain of Embarked: 0.0002
# |   |   |   |   |   -> Branch [SibSp = 0] with 21 rows
# |   |   |   |   |   |   Split on: Embarked
# |   |   |   |   |   |    - Info Gain of Embarked: 0.0184
# |   |   |   |   |   |   -> Branch [Embarked = 0] with 11 rows
# |   |   |   |   |   |   -> Branch [Embarked = 2] with 10 rows
# |   |   |   |   |   -> Branch [SibSp = 1] with 10 rows
# |   |   |   |   |   |   Split on: Embarked
# |   |   |   |   |   |    - Info Gain of Embarked: 0.0349
# |   |   |   |   |   |   -> Branch [Embarked = 0] with 3 rows
# |   |   |   |   |   |   -> Branch [Embarked = 2] with 7 rows
# |   |   |   |   -> Branch [Parch = 1] with 7 rows
# |   |   |   |   |   Split on: SibSp
# |   |   |   |   |    - Info Gain of SibSp: 0.1981
# |   |   |   |   |    - Info Gain of Embarked: 0.0202
# |   |   |   |   |   -> Branch [SibSp = 0] with 6 rows
# |   |   |   |   |   |   Split on: Embarked
# |   |   |   |   |   |    - Info Gain of Embarked: 0.2516
# |   |   |   |   |   |   -> Branch [Embarked = 0] with 4 rows
# |   |   |   |   |   |   -> Branch [Embarked = 2] with 2 rows
# |   |   |   |   |   -> Branch [SibSp = 1] with 1 rows
# |   |   |   |   -> Branch [Parch = 2] with 2 rows
# |   |   |   |   |   Split on: SibSp
# |   |   |   |   |    - Info Gain of SibSp: 1.0000
# |   |   |   |   |    - Info Gain of Embarked: 1.0000
# |   |   |   |   |   -> Branch [SibSp = 0] with 1 rows
# |   |   |   |   |   -> Branch [SibSp = 1] with 1 rows
# |   |   -> Branch [Age = 2] with 38 rows
# |   |   |   Split on: SibSp
# |   |   |    - Info Gain of SibSp: 0.0324
# |   |   |    - Info Gain of Parch: 0.0281
# |   |   |    - Info Gain of Fare: 0.0000
# |   |   |    - Info Gain of Embarked: 0.0224
# |   |   |   -> Branch [SibSp = 0] with 23 rows
# |   |   |   |   Split on: Parch
# |   |   |   |    - Info Gain of Parch: 0.0617
# |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |    - Info Gain of Embarked: 0.0125
# |   |   |   |   -> Branch [Parch = 0] with 20 rows
# |   |   |   |   |   Split on: Embarked
# |   |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |   |    - Info Gain of Embarked: 0.0022
# |   |   |   |   |   -> Branch [Embarked = 0] with 4 rows
# |   |   |   |   |   |   Split on: Fare
# |   |   |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |   |   |   -> Branch [Fare = 1] with 4 rows
# |   |   |   |   |   -> Branch [Embarked = 2] with 16 rows
# |   |   |   |   |   |   Split on: Fare
# |   |   |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |   |   |   -> Branch [Fare = 1] with 16 rows
# |   |   |   |   -> Branch [Parch = 1] with 2 rows
# |   |   |   |   -> Branch [Parch = 2] with 1 rows
# |   |   |   -> Branch [SibSp = 1] with 13 rows
# |   |   |   |   Split on: Embarked
# |   |   |   |    - Info Gain of Parch: 0.0146
# |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |    - Info Gain of Embarked: 0.1071
# |   |   |   |   -> Branch [Embarked = 0] with 6 rows
# |   |   |   |   |   Split on: Parch
# |   |   |   |   |    - Info Gain of Parch: 0.0441
# |   |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |   |   -> Branch [Parch = 0] with 4 rows
# |   |   |   |   |   |   Split on: Fare
# |   |   |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |   |   |   -> Branch [Fare = 1] with 4 rows
# |   |   |   |   |   -> Branch [Parch = 1] with 2 rows
# |   |   |   |   |   |   Split on: Fare
# |   |   |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |   |   |   -> Branch [Fare = 1] with 2 rows
# |   |   |   |   -> Branch [Embarked = 2] with 7 rows
# |   |   |   |   |   Split on: Parch
# |   |   |   |   |    - Info Gain of Parch: 0.0760
# |   |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |   |   -> Branch [Parch = 0] with 6 rows
# |   |   |   |   |   |   Split on: Fare
# |   |   |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |   |   |   -> Branch [Fare = 1] with 6 rows
# |   |   |   |   |   -> Branch [Parch = 1] with 1 rows
# |   |   |   -> Branch [SibSp = 2] with 2 rows
# |   |   |   |   Split on: Embarked
# |   |   |   |    - Info Gain of Parch: 0.0000
# |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |    - Info Gain of Embarked: 1.0000
# |   |   |   |   -> Branch [Embarked = 1] with 1 rows
# |   |   |   |   -> Branch [Embarked = 2] with 1 rows
# |   |   -> Branch [Age = 3] with 12 rows
# |   |   |   Split on: Parch
# |   |   |    - Info Gain of SibSp: 0.0230
# |   |   |    - Info Gain of Parch: 0.0364
# |   |   |    - Info Gain of Fare: 0.0000
# |   |   |    - Info Gain of Embarked: 0.0364
# |   |   |   -> Branch [Parch = 0] with 9 rows
# |   |   |   |   Split on: Embarked
# |   |   |   |    - Info Gain of SibSp: 0.0000
# |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |    - Info Gain of Embarked: 0.0431
# |   |   |   |   -> Branch [Embarked = 0] with 2 rows
# |   |   |   |   -> Branch [Embarked = 2] with 7 rows
# |   |   |   |   |   Split on: SibSp
# |   |   |   |   |    - Info Gain of SibSp: 0.0000
# |   |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |   |   -> Branch [SibSp = 0] with 7 rows
# |   |   |   |   |   |   Split on: Fare
# |   |   |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |   |   |   -> Branch [Fare = 1] with 7 rows
# |   |   |   -> Branch [Parch = 1] with 2 rows
# |   |   |   -> Branch [Parch = 4] with 1 rows
# |   -> Branch [Pclass = 2] with 99 rows
# |   |   Split on: Age
# |   |    - Info Gain of Age: 0.1652
# |   |    - Info Gain of SibSp: 0.0251
# |   |    - Info Gain of Parch: 0.1126
# |   |    - Info Gain of Fare: 0.0181
# |   |    - Info Gain of Embarked: 0.0028
# |   |   -> Branch [Age = 0] with 19 rows
# |   |   |   Split on: Parch
# |   |   |    - Info Gain of SibSp: 0.2906
# |   |   |    - Info Gain of Parch: 0.5307
# |   |   |    - Info Gain of Fare: 0.1670
# |   |   |    - Info Gain of Embarked: 0.0506
# |   |   |   -> Branch [Parch = 0] with 9 rows
# |   |   |   |   Split on: Fare
# |   |   |   |    - Info Gain of SibSp: 0.0000
# |   |   |   |    - Info Gain of Fare: 0.0431
# |   |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   |   -> Branch [Fare = 0] with 7 rows
# |   |   |   |   |   Split on: SibSp
# |   |   |   |   |    - Info Gain of SibSp: 0.0000
# |   |   |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   |   |   -> Branch [SibSp = 0] with 7 rows
# |   |   |   |   |   |   Split on: Embarked
# |   |   |   |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   |   |   |   -> Branch [Embarked = 2] with 7 rows
# |   |   |   |   -> Branch [Fare = 1] with 2 rows
# |   |   |   -> Branch [Parch = 1] with 8 rows
# |   |   |   |   Split on: SibSp
# |   |   |   |    - Info Gain of SibSp: 0.0259
# |   |   |   |    - Info Gain of Fare: 0.0259
# |   |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   |   -> Branch [SibSp = 1] with 7 rows
# |   |   |   |   |   Split on: Fare
# |   |   |   |   |    - Info Gain of Fare: 0.0345
# |   |   |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   |   |   -> Branch [Fare = 0] with 1 rows
# |   |   |   |   |   -> Branch [Fare = 1] with 6 rows
# |   |   |   |   |   |   Split on: Embarked
# |   |   |   |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   |   |   |   -> Branch [Embarked = 2] with 6 rows
# |   |   |   |   -> Branch [SibSp = 2] with 1 rows
# |   |   |   -> Branch [Parch = 2] with 2 rows
# |   |   -> Branch [Age = 1] with 59 rows
# |   |   |   Split on: Parch
# |   |   |    - Info Gain of SibSp: 0.0060
# |   |   |    - Info Gain of Parch: 0.0095
# |   |   |    - Info Gain of Fare: 0.0005
# |   |   |    - Info Gain of Embarked: 0.0095
# |   |   |   -> Branch [Parch = 0] with 52 rows
# |   |   |   |   Split on: Embarked
# |   |   |   |    - Info Gain of SibSp: 0.0079
# |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |    - Info Gain of Embarked: 0.0087
# |   |   |   |   -> Branch [Embarked = 0] with 5 rows
# |   |   |   |   -> Branch [Embarked = 2] with 47 rows
# |   |   |   |   |   Split on: SibSp
# |   |   |   |   |    - Info Gain of SibSp: 0.0128
# |   |   |   |   |    - Info Gain of Fare: 0.0003
# |   |   |   |   |   -> Branch [SibSp = 0] with 36 rows
# |   |   |   |   |   |   Split on: Fare
# |   |   |   |   |   |    - Info Gain of Fare: 0.0097
# |   |   |   |   |   |   -> Branch [Fare = 0] with 32 rows
# |   |   |   |   |   |   -> Branch [Fare = 1] with 4 rows
# |   |   |   |   |   -> Branch [SibSp = 1] with 8 rows
# |   |   |   |   |   |   Split on: Fare
# |   |   |   |   |   |    - Info Gain of Fare: 0.0259
# |   |   |   |   |   |   -> Branch [Fare = 0] with 1 rows
# |   |   |   |   |   |   -> Branch [Fare = 1] with 7 rows
# |   |   |   |   |   -> Branch [SibSp = 2] with 3 rows
# |   |   |   -> Branch [Parch = 1] with 4 rows
# |   |   |   -> Branch [Parch = 2] with 3 rows
# |   |   -> Branch [Age = 2] with 18 rows
# |   |   |   Split on: Fare
# |   |   |    - Info Gain of SibSp: 0.0270
# |   |   |    - Info Gain of Parch: 0.0097
# |   |   |    - Info Gain of Fare: 0.0410
# |   |   |    - Info Gain of Embarked: 0.0047
# |   |   |   -> Branch [Fare = 0] with 11 rows
# |   |   |   |   Split on: Embarked
# |   |   |   |    - Info Gain of SibSp: 0.0000
# |   |   |   |    - Info Gain of Parch: 0.0000
# |   |   |   |    - Info Gain of Embarked: 0.0131
# |   |   |   |   -> Branch [Embarked = 1] with 1 rows
# |   |   |   |   -> Branch [Embarked = 2] with 10 rows
# |   |   |   |   |   Split on: SibSp
# |   |   |   |   |    - Info Gain of SibSp: 0.0000
# |   |   |   |   |    - Info Gain of Parch: 0.0000
# |   |   |   |   |   -> Branch [SibSp = 0] with 10 rows
# |   |   |   |   |   |   Split on: Parch
# |   |   |   |   |   |    - Info Gain of Parch: 0.0000
# |   |   |   |   |   |   -> Branch [Parch = 0] with 10 rows
# |   |   |   -> Branch [Fare = 1] with 7 rows
# |   |   -> Branch [Age = 3] with 3 rows
# |   |   |   Split on: SibSp
# |   |   |    - Info Gain of SibSp: 0.0000
# |   |   |    - Info Gain of Parch: 0.0000
# |   |   |    - Info Gain of Fare: 0.0000
# |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   -> Branch [SibSp = 0] with 3 rows
# |   |   |   |   Split on: Parch
# |   |   |   |    - Info Gain of Parch: 0.0000
# |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   |   -> Branch [Parch = 0] with 3 rows
# |   |   |   |   |   Split on: Fare
# |   |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   |   |   -> Branch [Fare = 0] with 3 rows
# |   |   |   |   |   |   Split on: Embarked
# |   |   |   |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   |   |   |   -> Branch [Embarked = 2] with 3 rows
# |   -> Branch [Pclass = 3] with 253 rows
# |   |   Split on: SibSp
# |   |    - Info Gain of Age: 0.0115
# |   |    - Info Gain of SibSp: 0.0177
# |   |    - Info Gain of Parch: 0.0080
# |   |    - Info Gain of Fare: 0.0033
# |   |    - Info Gain of Embarked: 0.0107
# |   |   -> Branch [SibSp = 0] with 193 rows
# |   |   |   Split on: Fare
# |   |   |    - Info Gain of Age: 0.0108
# |   |   |    - Info Gain of Parch: 0.0158
# |   |   |    - Info Gain of Fare: 0.0201
# |   |   |    - Info Gain of Embarked: 0.0070
# |   |   |   -> Branch [Fare = 0] with 181 rows
# |   |   |   |   Split on: Parch
# |   |   |   |    - Info Gain of Age: 0.0082
# |   |   |   |    - Info Gain of Parch: 0.0197
# |   |   |   |    - Info Gain of Embarked: 0.0059
# |   |   |   |   -> Branch [Parch = 0] with 177 rows
# |   |   |   |   |   Split on: Age
# |   |   |   |   |    - Info Gain of Age: 0.0072
# |   |   |   |   |    - Info Gain of Embarked: 0.0024
# |   |   |   |   |   -> Branch [Age = 0] with 37 rows
# |   |   |   |   |   |   Split on: Embarked
# |   |   |   |   |   |    - Info Gain of Embarked: 0.0445
# |   |   |   |   |   |   -> Branch [Embarked = 0] with 2 rows
# |   |   |   |   |   |   -> Branch [Embarked = 1] with 1 rows
# |   |   |   |   |   |   -> Branch [Embarked = 2] with 34 rows
# |   |   |   |   |   -> Branch [Age = 1] with 113 rows
# |   |   |   |   |   |   Split on: Embarked
# |   |   |   |   |   |    - Info Gain of Embarked: 0.0010
# |   |   |   |   |   |   -> Branch [Embarked = 0] with 13 rows
# |   |   |   |   |   |   -> Branch [Embarked = 1] with 5 rows
# |   |   |   |   |   |   -> Branch [Embarked = 2] with 95 rows
# |   |   |   |   |   -> Branch [Age = 2] with 23 rows
# |   |   |   |   |   |   Split on: Embarked
# |   |   |   |   |   |    - Info Gain of Embarked: 0.0120
# |   |   |   |   |   |   -> Branch [Embarked = 0] with 1 rows
# |   |   |   |   |   |   -> Branch [Embarked = 1] with 1 rows
# |   |   |   |   |   |   -> Branch [Embarked = 2] with 21 rows
# |   |   |   |   |   -> Branch [Age = 3] with 4 rows
# |   |   |   |   -> Branch [Parch = 1] with 3 rows
# |   |   |   |   |   Split on: Age
# |   |   |   |   |    - Info Gain of Age: 0.9183
# |   |   |   |   |    - Info Gain of Embarked: 0.2516
# |   |   |   |   |   -> Branch [Age = 0] with 2 rows
# |   |   |   |   |   -> Branch [Age = 2] with 1 rows
# |   |   |   |   -> Branch [Parch = 2] with 1 rows
# |   |   |   -> Branch [Fare = 1] with 12 rows
# |   |   |   |   Split on: Parch
# |   |   |   |    - Info Gain of Age: 0.0699
# |   |   |   |    - Info Gain of Parch: 0.1707
# |   |   |   |    - Info Gain of Embarked: 0.0041
# |   |   |   |   -> Branch [Parch = 0] with 10 rows
# |   |   |   |   |   Split on: Age
# |   |   |   |   |    - Info Gain of Age: 0.0790
# |   |   |   |   |    - Info Gain of Embarked: 0.0074
# |   |   |   |   |   -> Branch [Age = 0] with 1 rows
# |   |   |   |   |   -> Branch [Age = 1] with 9 rows
# |   |   |   |   |   |   Split on: Embarked
# |   |   |   |   |   |    - Info Gain of Embarked: 0.1427
# |   |   |   |   |   |   -> Branch [Embarked = 0] with 1 rows
# |   |   |   |   |   |   -> Branch [Embarked = 2] with 8 rows
# |   |   |   |   -> Branch [Parch = 1] with 1 rows
# |   |   |   |   -> Branch [Parch = 2] with 1 rows
# |   |   -> Branch [SibSp = 1] with 35 rows
# |   |   |   Split on: Age
# |   |   |    - Info Gain of Age: 0.1847
# |   |   |    - Info Gain of Parch: 0.0611
# |   |   |    - Info Gain of Fare: 0.0002
# |   |   |    - Info Gain of Embarked: 0.0184
# |   |   |   -> Branch [Age = 0] with 15 rows
# |   |   |   |   Split on: Parch
# |   |   |   |    - Info Gain of Parch: 0.1355
# |   |   |   |    - Info Gain of Fare: 0.0280
# |   |   |   |    - Info Gain of Embarked: 0.0012
# |   |   |   |   -> Branch [Parch = 0] with 4 rows
# |   |   |   |   |   Split on: Embarked
# |   |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |   |    - Info Gain of Embarked: 0.3113
# |   |   |   |   |   -> Branch [Embarked = 0] with 1 rows
# |   |   |   |   |   -> Branch [Embarked = 2] with 3 rows
# |   |   |   |   |   |   Split on: Fare
# |   |   |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |   |   |   -> Branch [Fare = 0] with 3 rows
# |   |   |   |   -> Branch [Parch = 1] with 9 rows
# |   |   |   |   |   Split on: Fare
# |   |   |   |   |    - Info Gain of Fare: 0.0911
# |   |   |   |   |    - Info Gain of Embarked: 0.0183
# |   |   |   |   |   -> Branch [Fare = 0] with 4 rows
# |   |   |   |   |   |   Split on: Embarked
# |   |   |   |   |   |    - Info Gain of Embarked: 0.3113
# |   |   |   |   |   |   -> Branch [Embarked = 0] with 2 rows
# |   |   |   |   |   |   -> Branch [Embarked = 2] with 2 rows
# |   |   |   |   |   -> Branch [Fare = 1] with 5 rows
# |   |   |   |   |   |   Split on: Embarked
# |   |   |   |   |   |    - Info Gain of Embarked: 0.1710
# |   |   |   |   |   |   -> Branch [Embarked = 0] with 1 rows
# |   |   |   |   |   |   -> Branch [Embarked = 2] with 4 rows
# |   |   |   |   -> Branch [Parch = 2] with 1 rows
# |   |   |   |   -> Branch [Parch = 3] with 1 rows
# |   |   |   -> Branch [Age = 1] with 20 rows
# |   |   |   |   Split on: Fare
# |   |   |   |    - Info Gain of Parch: 0.0321
# |   |   |   |    - Info Gain of Fare: 0.0519
# |   |   |   |    - Info Gain of Embarked: 0.0121
# |   |   |   |   -> Branch [Fare = 0] with 10 rows
# |   |   |   |   |   Split on: Embarked
# |   |   |   |   |    - Info Gain of Parch: 0.0341
# |   |   |   |   |    - Info Gain of Embarked: 0.0548
# |   |   |   |   |   -> Branch [Embarked = 0] with 2 rows
# |   |   |   |   |   -> Branch [Embarked = 1] with 1 rows
# |   |   |   |   |   -> Branch [Embarked = 2] with 7 rows
# |   |   |   |   |   |   Split on: Parch
# |   |   |   |   |   |    - Info Gain of Parch: 0.0345
# |   |   |   |   |   |   -> Branch [Parch = 0] with 6 rows
# |   |   |   |   |   |   -> Branch [Parch = 1] with 1 rows
# |   |   |   |   -> Branch [Fare = 1] with 10 rows
# |   |   -> Branch [SibSp = 2] with 6 rows
# |   |   -> Branch [SibSp = 3] with 3 rows
# |   |   -> Branch [SibSp = 4] with 12 rows
# |   |   |   Split on: Parch
# |   |   |    - Info Gain of Age: 0.0000
# |   |   |    - Info Gain of Parch: 0.1842
# |   |   |    - Info Gain of Fare: 0.0000
# |   |   |    - Info Gain of Embarked: 0.0514
# |   |   |   -> Branch [Parch = 1] with 9 rows
# |   |   |   -> Branch [Parch = 2] with 3 rows
# |   |   |   |   Split on: Age
# |   |   |   |    - Info Gain of Age: 0.0000
# |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   |   -> Branch [Age = 0] with 3 rows
# |   |   |   |   |   Split on: Fare
# |   |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   |   |   -> Branch [Fare = 1] with 3 rows
# |   |   |   |   |   |   Split on: Embarked
# |   |   |   |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   |   |   |   -> Branch [Embarked = 2] with 3 rows
# |   |   -> Branch [SibSp = 5] with 4 rows
# -> Branch [Sex = 1] with 259 rows
# |   Split on: Pclass
# |    - Info Gain of Pclass: 0.2267
# |    - Info Gain of Age: 0.0099
# |    - Info Gain of SibSp: 0.0316
# |    - Info Gain of Parch: 0.0419
# |    - Info Gain of Fare: 0.0272
# |    - Info Gain of Embarked: 0.0329
# |   -> Branch [Pclass = 1] with 83 rows
# |   |   Split on: Parch
# |   |    - Info Gain of Age: 0.0065
# |   |    - Info Gain of SibSp: 0.0092
# |   |    - Info Gain of Parch: 0.0408
# |   |    - Info Gain of Fare: 0.0000
# |   |    - Info Gain of Embarked: 0.0025
# |   |   -> Branch [Parch = 0] with 54 rows
# |   |   |   Split on: Age
# |   |   |    - Info Gain of Age: 0.0331
# |   |   |    - Info Gain of SibSp: 0.0159
# |   |   |    - Info Gain of Fare: 0.0000
# |   |   |    - Info Gain of Embarked: 0.0178
# |   |   |   -> Branch [Age = 0] with 6 rows
# |   |   |   -> Branch [Age = 1] with 31 rows
# |   |   |   -> Branch [Age = 2] with 16 rows
# |   |   |   |   Split on: SibSp
# |   |   |   |    - Info Gain of SibSp: 0.0655
# |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |    - Info Gain of Embarked: 0.0351
# |   |   |   |   -> Branch [SibSp = 0] with 8 rows
# |   |   |   |   |   Split on: Embarked
# |   |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |   |    - Info Gain of Embarked: 0.0924
# |   |   |   |   |   -> Branch [Embarked = 0] with 5 rows
# |   |   |   |   |   |   Split on: Fare
# |   |   |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |   |   |   -> Branch [Fare = 1] with 5 rows
# |   |   |   |   |   -> Branch [Embarked = 2] with 3 rows
# |   |   |   |   -> Branch [SibSp = 1] with 7 rows
# |   |   |   |   -> Branch [SibSp = 2] with 1 rows
# |   |   |   -> Branch [Age = 3] with 1 rows
# |   |   -> Branch [Parch = 1] with 16 rows
# |   |   -> Branch [Parch = 2] with 13 rows
# |   |   |   Split on: SibSp
# |   |   |    - Info Gain of Age: 0.0072
# |   |   |    - Info Gain of SibSp: 0.3117
# |   |   |    - Info Gain of Fare: 0.0000
# |   |   |    - Info Gain of Embarked: 0.0641
# |   |   |   -> Branch [SibSp = 0] with 5 rows
# |   |   |   -> Branch [SibSp = 1] with 4 rows
# |   |   |   |   Split on: Age
# |   |   |   |    - Info Gain of Age: 0.0000
# |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   |   -> Branch [Age = 0] with 2 rows
# |   |   |   |   |   Split on: Fare
# |   |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   |   |   -> Branch [Fare = 1] with 2 rows
# |   |   |   |   |   |   Split on: Embarked
# |   |   |   |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   |   |   |   -> Branch [Embarked = 2] with 2 rows
# |   |   |   |   -> Branch [Age = 1] with 2 rows
# |   |   |   |   |   Split on: Fare
# |   |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   |   |   -> Branch [Fare = 1] with 2 rows
# |   |   |   |   |   |   Split on: Embarked
# |   |   |   |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   |   |   |   -> Branch [Embarked = 2] with 2 rows
# |   |   |   -> Branch [SibSp = 2] with 2 rows
# |   |   |   -> Branch [SibSp = 3] with 2 rows
# |   -> Branch [Pclass = 2] with 74 rows
# |   |   Split on: Age
# |   |    - Info Gain of Age: 0.0340
# |   |    - Info Gain of SibSp: 0.0094
# |   |    - Info Gain of Parch: 0.0294
# |   |    - Info Gain of Fare: 0.0031
# |   |    - Info Gain of Embarked: 0.0140
# |   |   -> Branch [Age = 0] with 16 rows
# |   |   -> Branch [Age = 1] with 45 rows
# |   |   |   Split on: Parch
# |   |   |    - Info Gain of SibSp: 0.0119
# |   |   |    - Info Gain of Parch: 0.0194
# |   |   |    - Info Gain of Fare: 0.0003
# |   |   |    - Info Gain of Embarked: 0.0159
# |   |   |   -> Branch [Parch = 0] with 30 rows
# |   |   |   |   Split on: Embarked
# |   |   |   |    - Info Gain of SibSp: 0.0064
# |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |    - Info Gain of Embarked: 0.0218
# |   |   |   |   -> Branch [Embarked = 0] with 3 rows
# |   |   |   |   -> Branch [Embarked = 1] with 1 rows
# |   |   |   |   -> Branch [Embarked = 2] with 26 rows
# |   |   |   |   |   Split on: SibSp
# |   |   |   |   |    - Info Gain of SibSp: 0.0112
# |   |   |   |   |    - Info Gain of Fare: 0.0001
# |   |   |   |   |   -> Branch [SibSp = 0] with 19 rows
# |   |   |   |   |   |   Split on: Fare
# |   |   |   |   |   |    - Info Gain of Fare: 0.0179
# |   |   |   |   |   |   -> Branch [Fare = 0] with 17 rows
# |   |   |   |   |   |   -> Branch [Fare = 1] with 2 rows
# |   |   |   |   |   -> Branch [SibSp = 1] with 6 rows
# |   |   |   |   |   |   Split on: Fare
# |   |   |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |   |   |   -> Branch [Fare = 1] with 6 rows
# |   |   |   |   |   -> Branch [SibSp = 3] with 1 rows
# |   |   |   -> Branch [Parch = 1] with 9 rows
# |   |   |   |   Split on: SibSp
# |   |   |   |    - Info Gain of SibSp: 0.0699
# |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   |   -> Branch [SibSp = 0] with 2 rows
# |   |   |   |   -> Branch [SibSp = 1] with 6 rows
# |   |   |   |   |   Split on: Fare
# |   |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   |   |   -> Branch [Fare = 1] with 6 rows
# |   |   |   |   |   |   Split on: Embarked
# |   |   |   |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   |   |   |   -> Branch [Embarked = 2] with 6 rows
# |   |   |   |   -> Branch [SibSp = 2] with 1 rows
# |   |   |   -> Branch [Parch = 2] with 5 rows
# |   |   |   -> Branch [Parch = 3] with 1 rows
# |   |   -> Branch [Age = 2] with 13 rows
# |   |   |   Split on: Parch
# |   |   |    - Info Gain of SibSp: 0.0072
# |   |   |    - Info Gain of Parch: 0.1201
# |   |   |    - Info Gain of Fare: 0.0072
# |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   -> Branch [Parch = 0] with 8 rows
# |   |   |   |   Split on: SibSp
# |   |   |   |    - Info Gain of SibSp: 0.0738
# |   |   |   |    - Info Gain of Fare: 0.0157
# |   |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   |   -> Branch [SibSp = 0] with 6 rows
# |   |   |   |   |   Split on: Fare
# |   |   |   |   |    - Info Gain of Fare: 0.0484
# |   |   |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   |   |   -> Branch [Fare = 0] with 5 rows
# |   |   |   |   |   |   Split on: Embarked
# |   |   |   |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   |   |   |   -> Branch [Embarked = 2] with 5 rows
# |   |   |   |   |   -> Branch [Fare = 1] with 1 rows
# |   |   |   |   -> Branch [SibSp = 1] with 2 rows
# |   |   |   |   |   Split on: Fare
# |   |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   |   |   -> Branch [Fare = 1] with 2 rows
# |   |   |   |   |   |   Split on: Embarked
# |   |   |   |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   |   |   |   -> Branch [Embarked = 2] with 2 rows
# |   |   |   -> Branch [Parch = 1] with 3 rows
# |   |   |   -> Branch [Parch = 2] with 1 rows
# |   |   |   -> Branch [Parch = 3] with 1 rows
# |   -> Branch [Pclass = 3] with 102 rows
# |   |   Split on: Age
# |   |    - Info Gain of Age: 0.0846
# |   |    - Info Gain of SibSp: 0.0447
# |   |    - Info Gain of Parch: 0.0390
# |   |    - Info Gain of Fare: 0.0139
# |   |    - Info Gain of Embarked: 0.0302
# |   |   -> Branch [Age = 0] with 47 rows
# |   |   |   Split on: SibSp
# |   |   |    - Info Gain of SibSp: 0.1467
# |   |   |    - Info Gain of Parch: 0.0473
# |   |   |    - Info Gain of Fare: 0.0559
# |   |   |    - Info Gain of Embarked: 0.0857
# |   |   |   -> Branch [SibSp = 0] with 22 rows
# |   |   |   |   Split on: Embarked
# |   |   |   |    - Info Gain of Parch: 0.0014
# |   |   |   |    - Info Gain of Fare: 0.0005
# |   |   |   |    - Info Gain of Embarked: 0.0341
# |   |   |   |   -> Branch [Embarked = 0] with 6 rows
# |   |   |   |   |   Split on: Parch
# |   |   |   |   |    - Info Gain of Parch: 0.1258
# |   |   |   |   |    - Info Gain of Fare: 0.1092
# |   |   |   |   |   -> Branch [Parch = 0] with 3 rows
# |   |   |   |   |   |   Split on: Fare
# |   |   |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |   |   |   -> Branch [Fare = 0] with 3 rows
# |   |   |   |   |   -> Branch [Parch = 1] with 2 rows
# |   |   |   |   |   |   Split on: Fare
# |   |   |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |   |   |   -> Branch [Fare = 0] with 2 rows
# |   |   |   |   |   -> Branch [Parch = 2] with 1 rows
# |   |   |   |   -> Branch [Embarked = 1] with 5 rows
# |   |   |   |   |   Split on: Parch
# |   |   |   |   |    - Info Gain of Parch: 0.0000
# |   |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |   |   -> Branch [Parch = 0] with 5 rows
# |   |   |   |   |   |   Split on: Fare
# |   |   |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |   |   |   -> Branch [Fare = 0] with 5 rows
# |   |   |   |   -> Branch [Embarked = 2] with 11 rows
# |   |   |   |   |   Split on: Parch
# |   |   |   |   |    - Info Gain of Parch: 0.0163
# |   |   |   |   |    - Info Gain of Fare: 0.0013
# |   |   |   |   |   -> Branch [Parch = 0] with 6 rows
# |   |   |   |   |   |   Split on: Fare
# |   |   |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |   |   |   -> Branch [Fare = 0] with 6 rows
# |   |   |   |   |   -> Branch [Parch = 1] with 3 rows
# |   |   |   |   |   |   Split on: Fare
# |   |   |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |   |   |   -> Branch [Fare = 0] with 3 rows
# |   |   |   |   |   -> Branch [Parch = 2] with 2 rows
# |   |   |   |   |   |   Split on: Fare
# |   |   |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |   |   |   -> Branch [Fare = 1] with 2 rows
# |   |   |   -> Branch [SibSp = 1] with 9 rows
# |   |   |   |   Split on: Parch
# |   |   |   |    - Info Gain of Parch: 0.0183
# |   |   |   |    - Info Gain of Fare: 0.0026
# |   |   |   |    - Info Gain of Embarked: 0.0072
# |   |   |   |   -> Branch [Parch = 0] with 6 rows
# |   |   |   |   |   Split on: Fare
# |   |   |   |   |    - Info Gain of Fare: 0.1909
# |   |   |   |   |    - Info Gain of Embarked: 0.0817
# |   |   |   |   |   -> Branch [Fare = 0] with 5 rows
# |   |   |   |   |   |   Split on: Embarked
# |   |   |   |   |   |    - Info Gain of Embarked: 0.0200
# |   |   |   |   |   |   -> Branch [Embarked = 0] with 3 rows
# |   |   |   |   |   |   -> Branch [Embarked = 2] with 2 rows
# |   |   |   |   |   -> Branch [Fare = 1] with 1 rows
# |   |   |   |   -> Branch [Parch = 1] with 3 rows
# |   |   |   |   |   Split on: Embarked
# |   |   |   |   |    - Info Gain of Fare: 0.2516
# |   |   |   |   |    - Info Gain of Embarked: 0.9183
# |   |   |   |   |   -> Branch [Embarked = 0] with 1 rows
# |   |   |   |   |   -> Branch [Embarked = 2] with 2 rows
# |   |   |   -> Branch [SibSp = 2] with 5 rows
# |   |   |   |   Split on: Parch
# |   |   |   |    - Info Gain of Parch: 0.9710
# |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |    - Info Gain of Embarked: 0.9710
# |   |   |   |   -> Branch [Parch = 0] with 1 rows
# |   |   |   |   -> Branch [Parch = 1] with 3 rows
# |   |   |   |   -> Branch [Parch = 2] with 1 rows
# |   |   |   -> Branch [SibSp = 3] with 4 rows
# |   |   |   -> Branch [SibSp = 4] with 6 rows
# |   |   |   |   Split on: Fare
# |   |   |   |    - Info Gain of Parch: 0.0000
# |   |   |   |    - Info Gain of Fare: 0.3167
# |   |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   |   -> Branch [Fare = 0] with 1 rows
# |   |   |   |   -> Branch [Fare = 1] with 5 rows
# |   |   |   |   |   Split on: Parch
# |   |   |   |   |    - Info Gain of Parch: 0.0000
# |   |   |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   |   |   -> Branch [Parch = 2] with 5 rows
# |   |   |   |   |   |   Split on: Embarked
# |   |   |   |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   |   |   |   -> Branch [Embarked = 2] with 5 rows
# |   |   |   -> Branch [SibSp = 5] with 1 rows
# |   |   -> Branch [Age = 1] with 46 rows
# |   |   |   Split on: SibSp
# |   |   |    - Info Gain of SibSp: 0.0736
# |   |   |    - Info Gain of Parch: 0.0682
# |   |   |    - Info Gain of Fare: 0.0042
# |   |   |    - Info Gain of Embarked: 0.0727
# |   |   |   -> Branch [SibSp = 0] with 29 rows
# |   |   |   |   Split on: Parch
# |   |   |   |    - Info Gain of Parch: 0.2336
# |   |   |   |    - Info Gain of Fare: 0.0012
# |   |   |   |    - Info Gain of Embarked: 0.0970
# |   |   |   |   -> Branch [Parch = 0] with 22 rows
# |   |   |   |   |   Split on: Embarked
# |   |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |   |    - Info Gain of Embarked: 0.0129
# |   |   |   |   |   -> Branch [Embarked = 1] with 3 rows
# |   |   |   |   |   |   Split on: Fare
# |   |   |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |   |   |   -> Branch [Fare = 0] with 3 rows
# |   |   |   |   |   -> Branch [Embarked = 2] with 19 rows
# |   |   |   |   |   |   Split on: Fare
# |   |   |   |   |   |    - Info Gain of Fare: 0.0000
# |   |   |   |   |   |   -> Branch [Fare = 0] with 19 rows
# |   |   |   |   -> Branch [Parch = 1] with 1 rows
# |   |   |   |   -> Branch [Parch = 2] with 3 rows
# |   |   |   |   -> Branch [Parch = 3] with 1 rows
# |   |   |   |   -> Branch [Parch = 4] with 1 rows
# |   |   |   |   -> Branch [Parch = 5] with 1 rows
# |   |   |   -> Branch [SibSp = 1] with 15 rows
# |   |   |   |   Split on: Fare
# |   |   |   |    - Info Gain of Parch: 0.0149
# |   |   |   |    - Info Gain of Fare: 0.3237
# |   |   |   |    - Info Gain of Embarked: 0.0407
# |   |   |   |   -> Branch [Fare = 0] with 6 rows
# |   |   |   |   -> Branch [Fare = 1] with 9 rows
# |   |   |   |   |   Split on: Parch
# |   |   |   |   |    - Info Gain of Parch: 0.0183
# |   |   |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   |   |   -> Branch [Parch = 0] with 4 rows
# |   |   |   |   |   |   Split on: Embarked
# |   |   |   |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   |   |   |   -> Branch [Embarked = 2] with 4 rows
# |   |   |   |   |   -> Branch [Parch = 1] with 3 rows
# |   |   |   |   |   |   Split on: Embarked
# |   |   |   |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   |   |   |   -> Branch [Embarked = 2] with 3 rows
# |   |   |   |   |   -> Branch [Parch = 5] with 2 rows
# |   |   |   |   |   |   Split on: Embarked
# |   |   |   |   |   |    - Info Gain of Embarked: 0.0000
# |   |   |   |   |   |   -> Branch [Embarked = 2] with 2 rows
# |   |   |   -> Branch [SibSp = 2] with 1 rows
# |   |   |   -> Branch [SibSp = 3] with 1 rows
# |   |   -> Branch [Age = 2] with 8 rows
# |   |   -> Branch [Age = 3] with 1 rows
#
# Final Decision Tree:
# {'Sex': {np.int64(0): {'Pclass': {np.int64(1): {'Age': {0: {'Parch': {np.int64(0): np.int64(0),
#                                                                       np.int64(2): {'SibSp': {np.int64(0): np.int64(1),
#                                                                                               np.int64(1): np.int64(1),
#                                                                                               np.int64(3): np.int64(0)}}}},
#                                                         1: {'Fare': {0: np.int64(0),
#                                                                      1: {'Parch': {np.int64(0): {'SibSp': {np.int64(0): {'Embarked': {np.int64(0): np.int64(1),
#                                                                                                                                       np.int64(2): np.int64(1)}},
#                                                                                                            np.int64(1): {'Embarked': {np.int64(0): np.int64(1),
#                                                                                                                                       np.int64(2): np.int64(0)}}}},
#                                                                                    np.int64(1): {'SibSp': {np.int64(0): {'Embarked': {np.int64(0): np.int64(0),
#                                                                                                                                       np.int64(2): np.int64(0)}},
#                                                                                                            np.int64(1): np.int64(1)}},
#                                                                                    np.int64(2): {'SibSp': {np.int64(0): np.int64(0),
#                                                                                                            np.int64(1): np.int64(1)}}}}}},
#                                                         2: {'SibSp': {np.int64(0): {'Parch': {np.int64(0): {'Embarked': {np.int64(0): {'Fare': {1: np.int64(0)}},
#                                                                                                                          np.int64(2): {'Fare': {1: np.int64(0)}}}},
#                                                                                               np.int64(1): np.int64(0),
#                                                                                               np.int64(2): np.int64(0)}},
#                                                                       np.int64(1): {'Embarked': {np.int64(0): {'Parch': {np.int64(0): {'Fare': {1: np.int64(1)}},
#                                                                                                                          np.int64(1): {'Fare': {1: np.int64(0)}}}},
#                                                                                                  np.int64(2): {'Parch': {np.int64(0): {'Fare': {1: np.int64(0)}},
#                                                                                                                          np.int64(1): np.int64(0)}}}},
#                                                                       np.int64(2): {'Embarked': {np.int64(1): np.int64(0),
#                                                                                                  np.int64(2): np.int64(1)}}}},
#                                                         3: {'Parch': {np.int64(0): {'Embarked': {np.int64(0): np.int64(0),
#                                                                                                  np.int64(2): {'SibSp': {np.int64(0): {'Fare': {1: np.int64(0)}}}}}},
#                                                                       np.int64(1): np.int64(0),
#                                                                       np.int64(4): np.int64(0)}}}},
#                                   np.int64(2): {'Age': {0: {'Parch': {np.int64(0): {'Fare': {0: {'SibSp': {np.int64(0): {'Embarked': {np.int64(2): np.int64(0)}}}},
#                                                                                              1: np.int64(0)}},
#                                                                       np.int64(1): {'SibSp': {np.int64(1): {'Fare': {0: np.int64(1),
#                                                                                                                      1: {'Embarked': {np.int64(2): np.int64(1)}}}},
#                                                                                               np.int64(2): np.int64(1)}},
#                                                                       np.int64(2): np.int64(1)}},
#                                                         1: {'Parch': {np.int64(0): {'Embarked': {np.int64(0): np.int64(0),
#                                                                                                  np.int64(2): {'SibSp': {np.int64(0): {'Fare': {0: np.int64(0),
#                                                                                                                                                 1: np.int64(0)}},
#                                                                                                                          np.int64(1): {'Fare': {0: np.int64(0),
#                                                                                                                                                 1: np.int64(0)}},
#                                                                                                                          np.int64(2): np.int64(0)}}}},
#                                                                       np.int64(1): np.int64(0),
#                                                                       np.int64(2): np.int64(0)}},
#                                                         2: {'Fare': {0: {'Embarked': {np.int64(1): np.int64(0),
#                                                                                       np.int64(2): {'SibSp': {np.int64(0): {'Parch': {np.int64(0): np.int64(0)}}}}}},
#                                                                      1: np.int64(0)}},
#                                                         3: {'SibSp': {np.int64(0): {'Parch': {np.int64(0): {'Fare': {0: {'Embarked': {np.int64(2): np.int64(0)}}}}}}}}}},
#                                   np.int64(3): {'SibSp': {np.int64(0): {'Fare': {0: {'Parch': {np.int64(0): {'Age': {0: {'Embarked': {np.int64(0): np.int64(0),
#                                                                                                                                       np.int64(1): np.int64(0),
#                                                                                                                                       np.int64(2): np.int64(0)}},
#                                                                                                                      1: {'Embarked': {np.int64(0): np.int64(0),
#                                                                                                                                       np.int64(1): np.int64(0),
#                                                                                                                                       np.int64(2): np.int64(0)}},
#                                                                                                                      2: {'Embarked': {np.int64(0): np.int64(0),
#                                                                                                                                       np.int64(1): np.int64(0),
#                                                                                                                                       np.int64(2): np.int64(0)}},
#                                                                                                                      3: np.int64(0)}},
#                                                                                                np.int64(1): {'Age': {0: np.int64(1),
#                                                                                                                      2: np.int64(0)}},
#                                                                                                np.int64(2): np.int64(0)}},
#                                                                                  1: {'Parch': {np.int64(0): {'Age': {0: np.int64(0),
#                                                                                                                      1: {'Embarked': {np.int64(0): np.int64(1),
#                                                                                                                                       np.int64(2): np.int64(0)}}}},
#                                                                                                np.int64(1): np.int64(0),
#                                                                                                np.int64(2): np.int64(1)}}}},
#                                                           np.int64(1): {'Age': {0: {'Parch': {np.int64(0): {'Embarked': {np.int64(0): np.int64(1),
#                                                                                                                          np.int64(2): {'Fare': {0: np.int64(0)}}}},
#                                                                                               np.int64(1): {'Fare': {0: {'Embarked': {np.int64(0): np.int64(0),
#                                                                                                                                       np.int64(2): np.int64(0)}},
#                                                                                                                      1: {'Embarked': {np.int64(0): np.int64(1),
#                                                                                                                                       np.int64(2): np.int64(0)}}}},
#                                                                                               np.int64(2): np.int64(1),
#                                                                                               np.int64(3): np.int64(0)}},
#                                                                                 1: {'Fare': {0: {'Embarked': {np.int64(0): np.int64(0),
#                                                                                                               np.int64(1): np.int64(0),
#                                                                                                               np.int64(2): {'Parch': {np.int64(0): np.int64(0),
#                                                                                                                                       np.int64(1): np.int64(0)}}}},
#                                                                                              1: np.int64(0)}}}},
#                                                           np.int64(2): np.int64(0),
#                                                           np.int64(3): np.int64(0),
#                                                           np.int64(4): {'Parch': {np.int64(1): np.int64(0),
#                                                                                   np.int64(2): {'Age': {0: {'Fare': {1: {'Embarked': {np.int64(2): np.int64(0)}}}}}}}},
#                                                           np.int64(5): np.int64(0)}}}},
#          np.int64(1): {'Pclass': {np.int64(1): {'Parch': {np.int64(0): {'Age': {0: np.int64(1),
#                                                                                 1: np.int64(1),
#                                                                                 2: {'SibSp': {np.int64(0): {'Embarked': {np.int64(0): {'Fare': {1: np.int64(1)}},
#                                                                                                                          np.int64(2): np.int64(1)}},
#                                                                                               np.int64(1): np.int64(1),
#                                                                                               np.int64(2): np.int64(1)}},
#                                                                                 3: np.int64(1)}},
#                                                           np.int64(1): np.int64(1),
#                                                           np.int64(2): {'SibSp': {np.int64(0): np.int64(1),
#                                                                                   np.int64(1): {'Age': {0: {'Fare': {1: {'Embarked': {np.int64(2): np.int64(0)}}}},
#                                                                                                         1: {'Fare': {1: {'Embarked': {np.int64(2): np.int64(0)}}}}}},
#                                                                                   np.int64(2): np.int64(1),
#                                                                                   np.int64(3): np.int64(1)}}}},
#                                   np.int64(2): {'Age': {0: np.int64(1),
#                                                         1: {'Parch': {np.int64(0): {'Embarked': {np.int64(0): np.int64(1),
#                                                                                                  np.int64(1): np.int64(1),
#                                                                                                  np.int64(2): {'SibSp': {np.int64(0): {'Fare': {0: np.int64(1),
#                                                                                                                                                 1: np.int64(1)}},
#                                                                                                                          np.int64(1): {'Fare': {1: np.int64(1)}},
#                                                                                                                          np.int64(3): np.int64(1)}}}},
#                                                                       np.int64(1): {'SibSp': {np.int64(0): np.int64(1),
#                                                                                               np.int64(1): {'Fare': {1: {'Embarked': {np.int64(2): np.int64(1)}}}},
#                                                                                               np.int64(2): np.int64(1)}},
#                                                                       np.int64(2): np.int64(1),
#                                                                       np.int64(3): np.int64(1)}},
#                                                         2: {'Parch': {np.int64(0): {'SibSp': {np.int64(0): {'Fare': {0: {'Embarked': {np.int64(2): np.int64(1)}},
#                                                                                                                      1: np.int64(1)}},
#                                                                                               np.int64(1): {'Fare': {1: {'Embarked': {np.int64(2): np.int64(0)}}}}}},
#                                                                       np.int64(1): np.int64(1),
#                                                                       np.int64(2): np.int64(1),
#                                                                       np.int64(3): np.int64(1)}}}},
#                                   np.int64(3): {'Age': {0: {'SibSp': {np.int64(0): {'Embarked': {np.int64(0): {'Parch': {np.int64(0): {'Fare': {0: np.int64(1)}},
#                                                                                                                          np.int64(1): {'Fare': {0: np.int64(0)}},
#                                                                                                                          np.int64(2): np.int64(1)}},
#                                                                                                  np.int64(1): {'Parch': {np.int64(0): {'Fare': {0: np.int64(1)}}}},
#                                                                                                  np.int64(2): {'Parch': {np.int64(0): {'Fare': {0: np.int64(0)}},
#                                                                                                                          np.int64(1): {'Fare': {0: np.int64(1)}},
#                                                                                                                          np.int64(2): {'Fare': {1: np.int64(0)}}}}}},
#                                                                       np.int64(1): {'Parch': {np.int64(0): {'Fare': {0: {'Embarked': {np.int64(0): np.int64(1),
#                                                                                                                                       np.int64(2): np.int64(0)}},
#                                                                                                                      1: np.int64(0)}},
#                                                                                               np.int64(1): {'Embarked': {np.int64(0): np.int64(0),
#                                                                                                                          np.int64(2): np.int64(1)}}}},
#                                                                       np.int64(2): {'Parch': {np.int64(0): np.int64(0),
#                                                                                               np.int64(1): np.int64(1),
#                                                                                               np.int64(2): np.int64(0)}},
#                                                                       np.int64(3): np.int64(0),
#                                                                       np.int64(4): {'Fare': {0: np.int64(1),
#                                                                                              1: {'Parch': {np.int64(2): {'Embarked': {np.int64(2): np.int64(0)}}}}}},
#                                                                       np.int64(5): np.int64(0)}},
#                                                         1: {'SibSp': {np.int64(0): {'Parch': {np.int64(0): {'Embarked': {np.int64(1): {'Fare': {0: np.int64(0)}},
#                                                                                                                          np.int64(2): {'Fare': {0: np.int64(1)}}}},
#                                                                                               np.int64(1): np.int64(1),
#                                                                                               np.int64(2): np.int64(1),
#                                                                                               np.int64(3): np.int64(1),
#                                                                                               np.int64(4): np.int64(0),
#                                                                                               np.int64(5): np.int64(0)}},
#                                                                       np.int64(1): {'Fare': {0: np.int64(0),
#                                                                                              1: {'Parch': {np.int64(0): {'Embarked': {np.int64(2): np.int64(0)}},
#                                                                                                            np.int64(1): {'Embarked': {np.int64(2): np.int64(1)}},
#                                                                                                            np.int64(5): {'Embarked': {np.int64(2): np.int64(0)}}}}}},
#                                                                       np.int64(2): np.int64(0),
#                                                                       np.int64(3): np.int64(1)}},
#                                                         2: np.int64(0),
#                                                         3: np.int64(1)}}}}}}

# %%
def predict(tree, sample):
    """
    Recursively traverse the tree for a single test sample (row).
    """
    if not isinstance(tree, dict):
        return tree  # If it's a leaf node, return the label

    # Get the current feature to split on
    feature = next(iter(tree))

    # Get the feature value for this sample
    feature_value = int(sample[feature])

    # Traverse to the subtree
    if feature_value in tree[feature]:
        return predict(tree[feature][feature_value], sample)
    else:
        # Fallback: unknown feature value (not seen in training)
        return 0  # or return majority class
    

testdata = pd.read_csv("../Datasets/test.csv")

# Simplify dataset: drop unnecessary columns
testdata = testdata[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']]

# Handle missing values
testdata.dropna(inplace=True)

# Convert categorical columns to numeric
testdata['Sex'] = testdata['Sex'].map({'male': 0, 'female': 1})
testdata['Embarked'] = testdata['Embarked'].map({'C': 0, 'Q': 1, 'S': 2})

# Discretize continuous features for clarity
testdata['Age'] = pd.cut(testdata['Age'], bins=3, labels=[0, 1, 2])
testdata['Fare'] = pd.qcut(testdata['Fare'], 3, labels=[0, 1, 2])

pred_y = []

for _, row in testdata.iterrows():
    pred_y.append(predict(decision_tree, row))

print(pred_y)
# Out:
# [np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), 0, np.int64(0), np.int64(0), 0, 0, np.int64(1), 0, 0, np.int64(0), np.int64(1), np.int64(0), 0, np.int64(0), 0, 0, 0, np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(0), 0, 0, np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(1), 0, np.int64(1), 0, 0, 0, np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(1), 0, np.int64(1), np.int64(0), np.int64(1), np.int64(1), 0, np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(0), 0, np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), 0, np.int64(1), np.int64(1), np.int64(1), np.int64(0), 0, np.int64(0), np.int64(0), np.int64(0), np.int64(0), 0, np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), 0, np.int64(0), np.int64(1), 0, np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(1), 0, np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(1), 0, np.int64(0), np.int64(0), np.int64(0), 0, 0, np.int64(1), np.int64(1), 0, np.int64(1), np.int64(1), np.int64(0), 0, np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(1), 0, np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(0), 0, np.int64(0), 0, 0, np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(0), 0, np.int64(1), np.int64(0), 0, np.int64(0), 0, np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(1), 0, 0, np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(0), 0, np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(0), 0, np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(1), 0, np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(1), 0, np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), 0, np.int64(1), 0, np.int64(0), np.int64(0), 0, np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(1), 0, np.int64(0), np.int64(0), np.int64(1), 0, np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(0), 0, np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(0), 0, np.int64(0), np.int64(1), np.int64(1), np.int64(0), 0, np.int64(0), 0, np.int64(1), np.int64(1), np.int64(0), 0, np.int64(1), np.int64(1), np.int64(0), np.int64(1), 0, np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(0), 0, 0, np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(0), 0, 0, np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(0)]

# %%
real_y = pd.read_csv("../Datasets/gender_submission.csv")

aligned_ground_truth = real_y.loc[testdata.index]
y_true = aligned_ground_truth['Survived'].values
y_pred = np.array(pred_y)


print(len(pred_y), len(y_true))

from sklearn.metrics import accuracy_score
print(f"Accuracy: {accuracy_score(y_true, y_pred):.4f}")
# Out:
# 331 331
# Accuracy: 0.8278

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /home/mra/Desktop/machine-learning-practice/venv/lib/python3.12/site-packages (1.7.0)
# Requirement already satisfied: numpy>=1.22.0 in /home/mra/Desktop/machine-learning-practice/venv/lib/python3.12/site-packages (from scikit-learn) (2.3.0)
# Requirement already satisfied: scipy>=1.8.0 in /home/mra/Desktop/machine-learning-practice/venv/lib/python3.12/site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /home/mra/Desktop/machine-learning-practice/venv/lib/python3.12/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/mra/Desktop/machine-learning-practice/venv/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
